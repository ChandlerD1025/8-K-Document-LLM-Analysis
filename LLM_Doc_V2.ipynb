# %%
import requests
import json
import pandas as pd
import time
from datetime import datetime
from bs4 import BeautifulSoup

# Step 1: Load ticker to CIK mapping
url = "https://www.sec.gov/files/company_tickers.json"
headers = {'User-Agent': 'YourName your@email.com'}  # SEC requires user-agent header

response = requests.get(url, headers=headers)
data = response.json()

# Convert to DataFrame for easier lookup
ticker_df = pd.DataFrame.from_dict(data, orient='index')
ticker_df['ticker'] = ticker_df['ticker'].str.upper()

# Create dictionary: Ticker -> CIK
ticker_to_cik = dict(zip(ticker_df['ticker'], ticker_df['cik_str']))

# Preview
print("Sample Mapping (Ticker to CIK):")
print(ticker_df.head())

# Function to get CIK from ticker
def get_cik(ticker):
    ticker = ticker.upper()
    cik = ticker_to_cik[ticker]
    return str(cik).zfill(10) if cik else None

# Test
print("\nCIK for AAPL:", get_cik("AAPL"))
# Out:
# Sample Mapping (Ticker to CIK):
#    cik_str ticker           title
# 0   320193   AAPL      Apple Inc.
# 1  1045810   NVDA     NVIDIA CORP
# 2   789019   MSFT  MICROSOFT CORP
# 3  1018724   AMZN  AMAZON COM INC
# 4  1652044  GOOGL   Alphabet Inc.
#
# CIK for AAPL: 0000320193

# %%
def fetch_8k_entries(cik, count=100, stock_ticker="UNKNOWN"):
    feed_url = f"https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={cik}&type=8-K&count={count}&output=atom"
    headers = {'User-Agent': 'YourName your@email.com'}

    response = requests.get(feed_url, headers=headers)
    soup = BeautifulSoup(response.content, 'xml')

    entries = []
    for entry in soup.find_all('entry'):
        title = entry.title.text
        filing_time = entry.updated.text
        filing_href = entry.link['href']

        # Fallback: If <company-name> tag is missing, use stock ticker
        company_tag = entry.find('company-name')
        company_name = company_tag.text if company_tag else f"CIK-{cik}"

        entries.append({
            'company_name': company_name,
            'stock_name': stock_ticker,
            'filing_time': filing_time,
            'filing_url': filing_href,
            'title': title
        })

    return entries

# Test it on AAPL again
apple_entries = fetch_8k_entries(get_cik("AAPL"), count=5, stock_ticker="AAPL")
pd.DataFrame(apple_entries)
# Out:
#      company_name stock_name                filing_time  \
# 0  CIK-0000320193       AAPL  2025-02-25T16:47:19-05:00
# 1  CIK-0000320193       AAPL  2025-01-30T16:30:23-05:00
# 2  CIK-0000320193       AAPL  2025-01-03T16:30:56-05:00
# 3  CIK-0000320193       AAPL  2024-10-31T16:30:25-04:00
# 4  CIK-0000320193       AAPL  2024-09-10T09:06:34-04:00
# 5  CIK-0000320193       AAPL  2024-08-26T17:20:33-04:00
# 6  CIK-0000320193       AAPL  2024-08-23T16:30:44-04:00
# 7  CIK-0000320193       AAPL  2024-08-01T16:30:26-04:00
# 8  CIK-0000320193       AAPL  2024-05-03T16:35:42-04:00
# 9  CIK-0000320193       AAPL  2024-05-02T16:30:34-04:00
#
#                                           filing_url                  title
# 0  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 1  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 2  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 3  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 4  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 5  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 6  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 7  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 8  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report
# 9  https://www.sec.gov/Archives/edgar/data/320193...  8-K  - Current report

# %%
def extract_main_document_text(filing_url):
    """
    Downloads the filing index page and retrieves the main filing document text.
    Returns plain text or None if anything fails.
    """
    headers = {'User-Agent': 'YourName your@email.com'}
    
    try:
        index_response = requests.get(filing_url, headers=headers)
        index_soup = BeautifulSoup(index_response.content, 'html.parser')
        
        table_rows = index_soup.select('table.tableFile tr')
        doc_link = None

        for row in table_rows:
            cells = row.find_all('td')
            if len(cells) >= 3:
                link_tag = cells[2].find('a')
                if link_tag and link_tag.has_attr('href'):
                    href = link_tag['href']
                    # Ignore viewer or index pages
                    if (
                        href.endswith(('.htm', '.html', '.txt')) and 
                        '-index' not in href and 
                        'ix?doc=' not in href
                    ):
                        doc_link = "https://www.sec.gov" + href
                        break

        if not doc_link:
            print(f"No valid document link found for {filing_url}")
            return None

        # Fetch the actual document content
        doc_response = requests.get(doc_link, headers=headers)
        doc_soup = BeautifulSoup(doc_response.content, 'html.parser')
        text = doc_soup.get_text(separator=' ', strip=True)

        return text

    except Exception as e:
        print(f"Error extracting filing text: {e}")
        return None

# Test it again
sample_url = apple_entries[1]['filing_url']
sample_text = extract_main_document_text(sample_url)
print(sample_text[:5000])
# Out:
# EX-99.1 2 a8-kex991q1202512282024.htm EX-99.1 Document Exhibit 99.1 Apple reports first quarter results All-time records for total company revenue and EPS Services revenue reaches new all-time high CUPERTINO, CALIFORNIA — Apple ® today announced financial results for its fiscal 2025 first quarter ended December 28, 2024. The Company posted quarterly revenue of $124.3 billion, up 4 percent year over year, and quarterly diluted earnings per share of $2.40, up 10 percent year over year. “Today Apple is reporting our best quarter ever, with revenue of $124.3 billion, up 4 percent from a year ago,” said Tim Cook, Apple’s CEO. “We were thrilled to bring customers our best-ever lineup of products and services during the holiday season. Through the power of Apple silicon, we’re unlocking new possibilities for our users with Apple Intelligence, which makes apps and experiences even better and more personal. And we’re excited that Apple Intelligence will be available in even more languages this April.” “Our record revenue and strong operating margins drove EPS to a new all-time record with double-digit growth and allowed us to return over $30 billion to shareholders,” said Kevan Parekh, Apple’s CFO. “We are also pleased that our installed base of active devices has reached a new all-time high across all products and geographic segments.” Apple’s board of directors has declared a cash dividend of $0.25 per share of the Company’s common stock. The dividend is payable on February 13, 2025, to shareholders of record as of the close of business on February 10, 2025. Apple will provide live streaming of its Q1 2025 financial results conference call beginning at 2:00 p.m. PT on January 30, 2025 at apple.com/investor/earnings-call. The webcast will be available for replay for approximately two weeks thereafter. Apple periodically provides information for investors on its corporate website, apple.com, and its investor relations website, investor.apple.com. This includes press releases and other information about financial performance, reports filed or furnished with the SEC, information on corporate governance, and details related to its annual meeting of shareholders. This press release contains forward-looking statements, within the meaning of the Private Securities Litigation Reform Act of 1995. These forward-looking statements include without limitation those about payment of the Company’s quarterly dividend and future business plans. These statements involve risks and uncertainties, and actual results may differ materially from any future results expressed or implied by the forward-looking statements. Risks and uncertainties include without limitation: effects of global and regional economic conditions, including as a result of government policies, geopolitical tensions, conflict, terrorism, natural disasters, and public health issues; risks relating to the design, manufacture, introduction, and transition of products and services in highly competitive and rapidly changing markets, including from reliance on third parties for components, technology, manufacturing, applications, support, and content; risks relating to information technology system failures, network disruptions, and failure to protect, loss of, or unauthorized access to, or release of, data; and effects of unfavorable legal proceedings, government investigations, and complex and changing laws and regulations. More information on these risks and other potential factors that could affect the Company’s business, reputation, results of operations, financial condition, and stock price is included in the Company’s filings with the SEC, including in the “Risk Factors” and “Management’s Discussion and Analysis of Financial Condition and Results of Operations” sections of the Company’s most recently filed periodic reports on Form 10-K and Form 10-Q and subsequent filings. The Company assumes no obligation to update any forward-looking statements, which speak only as of the date they a ...

# %%
def query_ollama_api(filing_text, model="mistral"):
    """
    Queries mistral locally via Ollama API and returns extracted product info.
    """
    prompt = f"""
You are analyzing a U.S. SEC Form 8-K filing. Your task is to identify whether the company is announcing a **new product or service**.

A new product can be:
- A physical or digital product
- A new service, software, or feature
- A major upgrade or generation of an existing product line

Only return a product if it is explicitly introduced or announced. Do not include vague mentions or general business updates.

Do NOT return anything related to:
- Financial results
- Executive changes
- Legal matters
- Business strategy without specific product details

Only include externally launched products or services available to customers. Do not include internal presentations or financial categories.
If multiple products are mentioned, return only the most prominent new product.

Output your answer in this strict JSON format:
```json
{{
  "new_product": "Product Name or null",
  "product_description": "Short one-sentence description (max 180 characters), or null"
}}

FILING TEXT:
\"\"\"
{filing_text[:5000]}
\"\"\"
"""

    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False,
    }

    try:
        response = requests.post("http://localhost:11434/api/generate", json=payload)
        response.raise_for_status()
        output = response.json()["response"]

        # Extract JSON part from LLM output
        start = output.find("{")
        end = output.rfind("}") + 1
        json_part = output[start:end]

        return json.loads(json_part)

    except Exception as e:
        print(f"Model API call failed: {e}")
        return {"new_product": None, "product_description": None}

# %%
def clean_null(value):
    return None if value in [None, "null", "Null", "NULL"] else value

def truncate_description(text, limit=180):
    if text and len(text) > limit:
        return text[:limit - 3] + "..."
    return text

def format_timestamp(iso_str):
    try:
        return datetime.fromisoformat(iso_str.replace("Z", "+00:00")).strftime("%Y-%m-%d %H:%M:%S")
    except Exception:
        return iso_str
        
# Processing file, feeding to Ollama model, and formating the response
def process_filings(entries, max_docs=100, output_csv="8k_product_releases.csv"):
    results = []
    for i, entry in enumerate(entries[:max_docs]):
        print(f"\n Processing filing {i+1}/{min(max_docs, len(entries))} for {entry['stock_name']}...")

        filing_text = extract_main_document_text(entry['filing_url'])
        if not filing_text:
            print("Skipping due to missing text.")
            continue

        response = query_ollama_api(filing_text)

        new_product = clean_null(response.get("new_product"))
        product_description = truncate_description(clean_null(response.get("product_description")))

        row = {
            "company_name": entry['company_name'],
            "stock_name": entry['stock_name'],
            "filing_time": format_timestamp(entry['filing_time']),
            "new_product": new_product,
            "product_description": product_description
        }

        print("Result:", row)
        results.append(row)

    # Save to CSV
    df = pd.DataFrame(results)
    df.to_csv(output_csv, index=False)
    print(f"\n Saved to {output_csv}")

    return results

# %%
# Run on Apple filings as test
apple_results = process_filings(apple_entries, max_docs=5)
# Out:
#  Processing filing 1/5 for AAPL...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2025-02-25 16:47:19', 'new_product': None, 'product_description': None}
#
#  Processing filing 2/5 for AAPL...
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2025-01-30 16:30:23', 'new_product': 'Apple Intelligence', 'product_description': 'A new software feature that makes apps and experiences even better and more personal.'}
#
#  Processing filing 3/5 for AAPL...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2025-01-03 16:30:56', 'new_product': None, 'product_description': None}
#
#  Processing filing 4/5 for AAPL...
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2024-10-31 16:30:25', 'new_product': 'iPhone 16 lineup', 'product_description': 'A new range of smartphones'}
#
#  Processing filing 5/5 for AAPL...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2024-09-10 09:06:34', 'new_product': None, 'product_description': None}
#
#  Saved to 8k_product_releases.csv

# %%
# List of companies most likely to have new products announced in their 8-ks
high_product_activity_tickers = [
    "AAPL",   # Apple – phones, chips, OS, services
    "MSFT",   # Microsoft – Windows, Surface, Azure, Copilot
    "GOOG",   # Google/Alphabet – Pixel, AI tools, services
    "AMZN",   # Amazon – Echo, AWS, devices
    "TSLA",   # Tesla – vehicles, energy, software
    "META",   # Meta – VR/AR, social platforms
    "NVDA",   # Nvidia – GPUs, AI hardware/software
    "INTC",   # Intel – chips, fabs, new SKUs
    "AMD",    # AMD – CPU/GPU launches
    "NFLX",   # Netflix – content platform updates
    "CRM",    # Salesforce – new cloud/software tools
    "ADBE",   # Adobe – Creative Cloud, Firefly AI, etc.
    "ORCL",   # Oracle – SaaS & AI product suite
    "IBM",    # IBM – AI, WatsonX, infrastructure tools
    "UBER",   # Uber – platform features, mobility services
    "PLTR",   # Palantir – always announcing something mysterious
    "SNOW",   # Snowflake – cloud data platform upgrades
    "ROKU",   # Consumer tech drops
    "COIN",   # Coinbase – new crypto features/tools
]
tickers = [t for t in high_product_activity_tickers if t in ticker_to_cik]
print("Tickers selected:", tickers)
# Out:
# Tickers selected: ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'META', 'NVDA', 'INTC', 'AMD', 'NFLX', 'CRM', 'ADBE', 'ORCL', 'IBM', 'UBER', 'PLTR', 'SNOW', 'ROKU', 'COIN']

# %%
# Iterating through tickers and pulling first 10 8-k filings
all_entries = []

for ticker in tickers:
    cik = get_cik(ticker)
    if not cik:
        print(f" No CIK for {ticker}, skipping.")
        continue

    try:
        entries = fetch_8k_entries(cik, count=10, stock_ticker=ticker)
        entries = entries[:8]
        all_entries.extend(entries)
    except Exception as e:
        print(f" Error fetching for {ticker}: {e}")

# %%
# Process all collected 8-Ks
all_results = process_filings(all_entries, max_docs=150, output_csv="multi_ticker_8k_products.csv")
# Out:
#  Processing filing 1/150 for AAPL...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2025-02-25 16:47:19', 'new_product': None, 'product_description': None}
#
#  Processing filing 2/150 for AAPL...
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2025-01-30 16:30:23', 'new_product': 'Apple Intelligence', 'product_description': 'A new software feature that makes apps and experiences even better and more personal, powered by Apple silicon.'}
#
#  Processing filing 3/150 for AAPL...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2025-01-03 16:30:56', 'new_product': None, 'product_description': None}
#
#  Processing filing 4/150 for AAPL...
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2024-10-31 16:30:25', 'new_product': 'iPhone 16 lineup', 'product_description': 'A new line of smartphones announced by Apple'}
#
#  Processing filing 5/150 for AAPL...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2024-09-10 09:06:34', 'new_product': None, 'product_description': None}
#
#  Processing filing 6/150 for AAPL...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2024-08-26 17:20:33', 'new_product': None, 'product_description': None}
#
#  Processing filing 7/150 for AAPL...
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2024-08-23 16:30:44', 'new_product': None, 'product_description': 'No new product or service was announced in this filing.'}
#
#  Processing filing 8/150 for AAPL...
# Result: {'company_name': 'CIK-0000320193', 'stock_name': 'AAPL', 'filing_time': '2024-08-01 16:30:26', 'new_product': 'Apple Intelligence', 'product_description': 'A breakthrough personal intelligence system that puts powerful, private generative AI models at the core of iPhone, iPad, and Mac.'}
#
#  Processing filing 9/150 for MSFT...
# Result: {'company_name': 'CIK-0000789019', 'stock_name': 'MSFT', 'filing_time': '2025-01-29 16:08:56', 'new_product': None, 'product_description': 'No new product announced in this filing.'}
#
#  Processing filing 10/150 for MSFT...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000789019', 'stock_name': 'MSFT', 'filing_time': '2025-01-22 17:15:39', 'new_product': None, 'product_description': None}
#
#  Processing filing 11/150 for MSFT...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0000789019', 'stock_name': 'MSFT', 'filing_time': '2024-12-11 16:01:27', 'new_product': None, 'product_description': None}
#
#  Processing filing 12/150 for MSFT...
# Result: {'company_name': 'CIK-0000789019', 'stock_name': 'MSFT', 'filing_time': '2024-12-03 16:00:37', 'new_product': None, 'product_description': None}
#
#  Processing filing 13/150 for MSFT...
# Result: {'company_name': 'CIK-0000789019', 'stock_name': 'MSFT', 'filing_time': '2024-10-30 16:04:07', 'new_product': 'Microsoft 365 Commercial cloud', 'product_description': 'A subscription service that provides access to productivity software and services, including Word, Excel, PowerPoint, OneDrive, and Teams.'}
#
#  Processing filing 14/150 for MSFT...
# Result: {'company_name': 'CIK-0000789019', 'stock_name': 'MSFT', 'filing_time': '2024-08-21 16:08:55', 'new_product': 'Microsoft 365 Commercial products and cloud services', 'product_description': 'A suite of productivity software and cloud services, including Office Commercial products, Enterprise Mobility + Security, Power BI per-user revenue, Windows Commercial products...'}
#
#  Processing filing 15/150 for MSFT...
# Result: {'company_name': 'CIK-0000789019', 'stock_name': 'MSFT', 'filing_time': '2024-07-30 16:03:22', 'new_product': None, 'product_description': 'No new product announced in this filing.'}
#
#  Processing filing 16/150 for MSFT...
# Result: {'company_name': 'CIK-0000789019', 'stock_name': 'MSFT', 'filing_time': '2024-04-25 16:03:19', 'new_product': 'Microsoft Copilot', 'product_description': 'Artificial Intelligence platform for transforming business outcomes across every role and industry'}
#
#  Processing filing 17/150 for GOOG...
# Result: {'company_name': 'CIK-0001652044', 'stock_name': 'GOOG', 'filing_time': '2025-03-18 08:43:32', 'new_product': 'Wiz Security Platform', 'product_description': 'An easy-to-use cloud security platform that connects to all major clouds and code environments, preventing cybersecurity incidents for organizations of all sizes.'}
#
#  Processing filing 18/150 for GOOG...
# Result: {'company_name': 'CIK-0001652044', 'stock_name': 'GOOG', 'filing_time': '2025-02-04 16:01:27', 'new_product': 'AI Overviews and Circle to Search', 'product_description': 'AI-powered improvements to Google Search increasing user engagement'}
#
#  Processing filing 19/150 for GOOG...
# Result: {'company_name': 'CIK-0001652044', 'stock_name': 'GOOG', 'filing_time': '2024-10-29 16:01:46', 'new_product': None, 'product_description': 'No new product announced in this filing'}
#
#  Processing filing 20/150 for GOOG...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001652044', 'stock_name': 'GOOG', 'filing_time': '2024-10-17 14:20:32', 'new_product': None, 'product_description': None}
#
#  Processing filing 21/150 for GOOG...
# Result: {'company_name': 'CIK-0001652044', 'stock_name': 'GOOG', 'filing_time': '2024-09-24 08:31:01', 'new_product': None, 'product_description': 'No new product announced in the provided filing text.'}
#
#  Processing filing 22/150 for GOOG...
# Result: {'company_name': 'CIK-0001652044', 'stock_name': 'GOOG', 'filing_time': '2024-08-05 20:08:50', 'new_product': None, 'product_description': None}
#
#  Processing filing 23/150 for GOOG...
# Result: {'company_name': 'CIK-0001652044', 'stock_name': 'GOOG', 'filing_time': '2024-07-23 16:01:54', 'new_product': None, 'product_description': 'No new product is explicitly introduced or announced in this filing.'}
#
#  Processing filing 24/150 for GOOG...
# Result: {'company_name': 'CIK-0001652044', 'stock_name': 'GOOG', 'filing_time': '2024-06-26 10:55:04', 'new_product': None, 'product_description': None}
#
#  Processing filing 25/150 for AMZN...
# Result: {'company_name': 'CIK-0001018724', 'stock_name': 'AMZN', 'filing_time': '2025-02-06 16:09:12', 'new_product': 'Trainium2 AI chip', 'product_description': 'A new artificial intelligence (AI) chip introduced by AWS'}
#
#  Processing filing 26/150 for AMZN...
# Result: {'company_name': 'CIK-0001018724', 'stock_name': 'AMZN', 'filing_time': '2024-10-31 16:13:57', 'new_product': 'All-new Kindle lineup', 'product_description': 'Amazon launched a new lineup of Kindle e-readers, which is significantly outperforming their expectations'}
#
#  Processing filing 27/150 for AMZN...
# Result: {'company_name': 'CIK-0001018724', 'stock_name': 'AMZN', 'filing_time': '2024-08-01 16:06:02', 'new_product': "Amazon's Stores business", 'product_description': 'Expansion of physical retail stores into South Africa'}
#
#  Processing filing 28/150 for AMZN...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001018724', 'stock_name': 'AMZN', 'filing_time': '2024-05-24 16:03:37', 'new_product': None, 'product_description': None}
#
#  Processing filing 29/150 for AMZN...
# Error extracting filing text: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  AssertionError: expected name token at '<![(V#1(2\\Y32.RXI/Y('
# Skipping due to missing text.
#
#  Processing filing 30/150 for AMZN...
# Result: {'company_name': 'CIK-0001018724', 'stock_name': 'AMZN', 'filing_time': '2024-05-03 16:41:53', 'new_product': None, 'product_description': None}
#
#  Processing filing 31/150 for AMZN...
# Result: {'company_name': 'CIK-0001018724', 'stock_name': 'AMZN', 'filing_time': '2024-04-30 16:10:34', 'new_product': None, 'product_description': None}
#
#  Processing filing 32/150 for AMZN...
# Result: {'company_name': 'CIK-0001018724', 'stock_name': 'AMZN', 'filing_time': '2024-04-10 18:24:36', 'new_product': None, 'product_description': None}
#
#  Processing filing 33/150 for TSLA...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001318605', 'stock_name': 'TSLA', 'filing_time': '2025-01-29 16:09:13', 'new_product': None, 'product_description': None}
#
#  Processing filing 34/150 for TSLA...
# Result: {'company_name': 'CIK-0001318605', 'stock_name': 'TSLA', 'filing_time': '2025-01-02 09:06:39', 'new_product': None, 'product_description': 'No new product was announced in this filing'}
#
#  Processing filing 35/150 for TSLA...
# Result: {'company_name': 'CIK-0001318605', 'stock_name': 'TSLA', 'filing_time': '2024-10-23 16:09:26', 'new_product': 'New vehicles – including more affordable models', 'product_description': None}
#
#  Processing filing 36/150 for TSLA...
# Result: {'company_name': 'CIK-0001318605', 'stock_name': 'TSLA', 'filing_time': '2024-10-02 09:06:34', 'new_product': None, 'product_description': 'No new product was explicitly announced'}
#
#  Processing filing 37/150 for TSLA...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001318605', 'stock_name': 'TSLA', 'filing_time': '2024-07-23 16:32:27', 'new_product': None, 'product_description': None}
#
#  Processing filing 38/150 for TSLA...
# Result: {'company_name': 'CIK-0001318605', 'stock_name': 'TSLA', 'filing_time': '2024-07-02 09:24:01', 'new_product': None, 'product_description': None}
#
#  Processing filing 39/150 for TSLA...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001318605', 'stock_name': 'TSLA', 'filing_time': '2024-06-14 06:02:55', 'new_product': None, 'product_description': None}
#
#  Processing filing 40/150 for TSLA...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001318605', 'stock_name': 'TSLA', 'filing_time': '2024-04-23 16:09:55', 'new_product': None, 'product_description': None}
#
#  Processing filing 41/150 for META...
# Result: {'company_name': 'CIK-0001326801', 'stock_name': 'META', 'filing_time': '2025-02-20 16:33:09', 'new_product': 'None', 'product_description': 'No new product announced in this filing'}
#
#  Processing filing 42/150 for META...
# Result: {'company_name': 'CIK-0001326801', 'stock_name': 'META', 'filing_time': '2025-01-29 16:47:14', 'new_product': 'Reality Labs', 'product_description': 'A new focus on Reality Labs, which includes work in the areas of augmented and virtual reality.'}
#
#  Processing filing 43/150 for META...
# Result: {'company_name': 'CIK-0001326801', 'stock_name': 'META', 'filing_time': '2025-01-06 16:40:45', 'new_product': None, 'product_description': None}
#
#  Processing filing 44/150 for META...
# Result: {'company_name': 'CIK-0001326801', 'stock_name': 'META', 'filing_time': '2024-10-30 16:08:12', 'new_product': None, 'product_description': None}
#
#  Processing filing 45/150 for META...
# Result: {'company_name': 'CIK-0001326801', 'stock_name': 'META', 'filing_time': '2024-09-10 16:53:12', 'new_product': None, 'product_description': 'No new product announced in this filing'}
#
#  Processing filing 46/150 for META...
# Result: {'company_name': 'CIK-0001326801', 'stock_name': 'META', 'filing_time': '2024-08-09 16:30:30', 'new_product': None, 'product_description': 'There is no new product announced in this filing.'}
#
#  Processing filing 47/150 for META...
# Result: {'company_name': 'CIK-0001326801', 'stock_name': 'META', 'filing_time': '2024-07-31 16:11:20', 'new_product': 'Meta AI assistant', 'product_description': 'First frontier-level open source AI model introduced by Meta Platforms'}
#
#  Processing filing 48/150 for META...
# Result: {'company_name': 'CIK-0001326801', 'stock_name': 'META', 'filing_time': '2024-05-31 16:14:51', 'new_product': None, 'product_description': None}
#
#  Processing filing 49/150 for NVDA...
# Result: {'company_name': 'CIK-0001045810', 'stock_name': 'NVDA', 'filing_time': '2025-03-07 17:09:13', 'new_product': None, 'product_description': 'No new product or service was announced in the provided filing'}
#
#  Processing filing 50/150 for NVDA...
# Result: {'company_name': 'CIK-0001045810', 'stock_name': 'NVDA', 'filing_time': '2025-02-26 16:21:32', 'new_product': None, 'product_description': None}
#
#  Processing filing 51/150 for NVDA...
# Result: {'company_name': 'CIK-0001045810', 'stock_name': 'NVDA', 'filing_time': '2025-01-17 16:59:50', 'new_product': None, 'product_description': None}
#
#  Processing filing 52/150 for NVDA...
# Result: {'company_name': 'CIK-0001045810', 'stock_name': 'NVDA', 'filing_time': '2024-11-20 16:21:20', 'new_product': 'NVIDIA Hopper H200', 'product_description': 'New AI infrastructure product: NVIDIA Hopper H200-powered instances now available in several cloud services'}
#
#  Processing filing 53/150 for NVDA...
# Result: {'company_name': 'CIK-0001045810', 'stock_name': 'NVDA', 'filing_time': '2024-11-07 16:35:26', 'new_product': None, 'product_description': None}
#
#  Processing filing 54/150 for NVDA...
# Result: {'company_name': 'CIK-0001045810', 'stock_name': 'NVDA', 'filing_time': '2024-08-28 16:21:16', 'new_product': 'Blackwell', 'product_description': 'A new product category, NVIDIA Blackwell is a new architecture B200 Tensor Core processor for data centers.'}
#
#  Processing filing 55/150 for NVDA...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001045810', 'stock_name': 'NVDA', 'filing_time': '2024-07-02 16:47:41', 'new_product': None, 'product_description': None}
#
#  Processing filing 56/150 for NVDA...
# Result: {'company_name': 'CIK-0001045810', 'stock_name': 'NVDA', 'filing_time': '2024-06-07 16:19:34', 'new_product': None, 'product_description': 'The text does not mention a new product or service.'}
#
#  Processing filing 57/150 for INTC...
# Result: {'company_name': 'CIK-0000050863', 'stock_name': 'INTC', 'filing_time': '2025-03-14 17:00:44', 'new_product': None, 'product_description': None}
#
#  Processing filing 58/150 for INTC...
# Result: {'company_name': 'CIK-0000050863', 'stock_name': 'INTC', 'filing_time': '2025-03-14 17:00:12', 'new_product': None, 'product_description': 'No new product or service is announced in this filing.'}
#
#  Processing filing 59/150 for INTC...
# Result: {'company_name': 'CIK-0000050863', 'stock_name': 'INTC', 'filing_time': '2025-02-28 17:22:51', 'new_product': None, 'product_description': 'No new product or service announced in this filing.'}
#
#  Processing filing 60/150 for INTC...
# Result: {'company_name': 'CIK-0000050863', 'stock_name': 'INTC', 'filing_time': '2025-01-30 16:13:45', 'new_product': None, 'product_description': None}
#
#  Processing filing 61/150 for INTC...
# Result: {'company_name': 'CIK-0000050863', 'stock_name': 'INTC', 'filing_time': '2024-12-05 08:30:58', 'new_product': None, 'product_description': ''}
#
#  Processing filing 62/150 for INTC...
# Result: {'company_name': 'CIK-0000050863', 'stock_name': 'INTC', 'filing_time': '2024-12-02 19:28:44', 'new_product': None, 'product_description': 'No new product announced in the given filing.'}
#
#  Processing filing 63/150 for INTC...
# Result: {'company_name': 'CIK-0000050863', 'stock_name': 'INTC', 'filing_time': '2024-11-27 17:00:19', 'new_product': "Intel's commercial semiconductor manufacturing projects", 'product_description': 'Advanced semiconductor manufacturing projects in Arizona, New Mexico, Ohio and Oregon'}
#
#  Processing filing 64/150 for INTC...
# Result: {'company_name': 'CIK-0000050863', 'stock_name': 'INTC', 'filing_time': '2024-10-31 16:07:17', 'new_product': 'Intel 18A', 'product_description': 'New process technology node introduced for foundry business'}
#
#  Processing filing 65/150 for AMD...
# Result: {'company_name': 'CIK-0000002488', 'stock_name': 'AMD', 'filing_time': '2025-03-24 16:17:24', 'new_product': None, 'product_description': 'This filing does not announce a new product or service.'}
#
#  Processing filing 66/150 for AMD...
# Result: {'company_name': 'CIK-0000002488', 'stock_name': 'AMD', 'filing_time': '2025-03-11 20:14:01', 'new_product': None, 'product_description': 'No new product is announced in this filing.'}
#
#  Processing filing 67/150 for AMD...
# Result: {'company_name': 'CIK-0000002488', 'stock_name': 'AMD', 'filing_time': '2025-02-24 17:20:12', 'new_product': None, 'product_description': None}
#
#  Processing filing 68/150 for AMD...
# Result: {'company_name': 'CIK-0000002488', 'stock_name': 'AMD', 'filing_time': '2025-02-04 16:17:17', 'new_product': None, 'product_description': None}
#
#  Processing filing 69/150 for AMD...
# Result: {'company_name': 'CIK-0000002488', 'stock_name': 'AMD', 'filing_time': '2024-11-18 16:17:24', 'new_product': None, 'product_description': 'No new product announced in the provided filing text.'}
#
#  Processing filing 70/150 for AMD...
# Result: {'company_name': 'CIK-0000002488', 'stock_name': 'AMD', 'filing_time': '2024-10-29 16:16:49', 'new_product': 'AMD EPYC 9005 Series processors', 'product_description': 'New high-performance data center processors with record-breaking performance and energy efficiency for diverse data center needs'}
#
#  Processing filing 71/150 for AMD...
# Result: {'company_name': 'CIK-0000002488', 'stock_name': 'AMD', 'filing_time': '2024-08-19 06:22:30', 'new_product': None, 'product_description': None}
#
#  Processing filing 72/150 for AMD...
# Result: {'company_name': 'CIK-0000002488', 'stock_name': 'AMD', 'filing_time': '2024-07-30 16:17:15', 'new_product': 'AMD Instinct MI325X accelerator', 'product_description': 'A new AI accelerator with leadership memory capacity and compute performance, planned to be available in Q4 2024'}
#
#  Processing filing 73/150 for NFLX...
# Result: {'company_name': 'CIK-0001065280', 'stock_name': 'NFLX', 'filing_time': '2025-01-21 16:02:20', 'new_product': 'Squid Game season 2', 'product_description': 'Second season of popular Netflix original series'}
#
#  Processing filing 74/150 for NFLX...
# Result: {'company_name': 'CIK-0001065280', 'stock_name': 'NFLX', 'filing_time': '2024-10-17 16:01:18', 'new_product': 'The Perfect Couple , Nobody Wants This, Tokyo Swindlers, Emily in Paris, Cobra Kai, Beverly Hills Cop: Axel F , Rebel Ridge, Squid Game S2', 'product_description': 'New series and films released on the streaming platform'}
#
#  Processing filing 75/150 for NFLX...
# Result: {'company_name': 'CIK-0001065280', 'stock_name': 'NFLX', 'filing_time': '2024-08-01 16:14:14', 'new_product': None, 'product_description': 'No new product announced in this filing.'}
#
#  Processing filing 76/150 for NFLX...
# Result: {'company_name': 'CIK-0001065280', 'stock_name': 'NFLX', 'filing_time': '2024-07-18 16:01:22', 'new_product': 'New, simpler and more intuitive TV homepage', 'product_description': 'A new, improved Netflix TV homepage for better discovery experience'}
#
#  Processing filing 77/150 for NFLX...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001065280', 'stock_name': 'NFLX', 'filing_time': '2024-06-07 17:15:39', 'new_product': None, 'product_description': None}
#
#  Processing filing 78/150 for NFLX...
# Result: {'company_name': 'CIK-0001065280', 'stock_name': 'NFLX', 'filing_time': '2024-04-18 16:02:24', 'new_product': 'Ads service', 'product_description': 'Netflix is scaling its ads service, aiming to become a more meaningful contributor to the business in 2025 and beyond.'}
#
#  Processing filing 79/150 for NFLX...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001065280', 'stock_name': 'NFLX', 'filing_time': '2024-01-23 16:02:17', 'new_product': None, 'product_description': None}
#
#  Processing filing 80/150 for NFLX...
# Result: {'company_name': 'CIK-0001065280', 'stock_name': 'NFLX', 'filing_time': '2023-12-08 17:01:44', 'new_product': None, 'product_description': 'No new product or service is announced in this filing'}
#
#  Processing filing 81/150 for CRM...
# Result: {'company_name': 'CIK-0001108524', 'stock_name': 'CRM', 'filing_time': '2025-02-26 16:03:55', 'new_product': 'Agentforce & Data Cloud', 'product_description': 'AI CRM platform, including Agentforce for customer service automation and Data Cloud for managing large data sets'}
#
#  Processing filing 82/150 for CRM...
# Result: {'company_name': 'CIK-0001108524', 'stock_name': 'CRM', 'filing_time': '2025-02-05 17:05:59', 'new_product': None, 'product_description': 'There is no new product or service announced in this filing.'}
#
#  Processing filing 83/150 for CRM...
# Result: {'company_name': 'CIK-0001108524', 'stock_name': 'CRM', 'filing_time': '2024-12-10 16:10:52', 'new_product': None, 'product_description': 'No new product announced in this filing.'}
#
#  Processing filing 84/150 for CRM...
# Result: {'company_name': 'CIK-0001108524', 'stock_name': 'CRM', 'filing_time': '2024-12-03 16:03:38', 'new_product': 'Agentforce', 'product_description': 'Complete AI system for enterprises built into the Salesforce Platform, revolutionizing global labor and reshaping industries'}
#
#  Processing filing 85/150 for CRM...
# Result: {'company_name': 'CIK-0001108524', 'stock_name': 'CRM', 'filing_time': '2024-11-05 16:09:32', 'new_product': None, 'product_description': None}
#
#  Processing filing 86/150 for CRM...
# Result: {'company_name': 'CIK-0001108524', 'stock_name': 'CRM', 'filing_time': '2024-09-05 16:37:31', 'new_product': 'Own Data Platform', 'product_description': 'A data platform that provides archiving, seeding, security, analytics capabilities to ensure the availability, compliance, and security of SaaS data'}
#
#  Processing filing 87/150 for CRM...
# Result: {'company_name': 'CIK-0001108524', 'stock_name': 'CRM', 'filing_time': '2024-08-28 16:02:42', 'new_product': 'Agentforce AI platform', 'product_description': 'Reimagining enterprise software for a world where humans work with autonomous agents.'}
#
#  Processing filing 88/150 for CRM...
# Result: {'company_name': 'CIK-0001108524', 'stock_name': 'CRM', 'filing_time': '2024-07-01 16:18:35', 'new_product': None, 'product_description': None}
#
#  Processing filing 89/150 for ADBE...
# Result: {'company_name': 'CIK-0000796343', 'stock_name': 'ADBE', 'filing_time': '2025-03-12 16:06:35', 'new_product': None, 'product_description': None}
#
#  Processing filing 90/150 for ADBE...
# Result: {'company_name': 'CIK-0000796343', 'stock_name': 'ADBE', 'filing_time': '2025-01-30 16:17:12', 'new_product': None, 'product_description': 'No new product or service is announced in this filing.'}
#
#  Processing filing 91/150 for ADBE...
# Result: {'company_name': 'CIK-0000796343', 'stock_name': 'ADBE', 'filing_time': '2025-01-17 16:05:22', 'new_product': None, 'product_description': 'No new product or service is announced in this filing.'}
#
#  Processing filing 92/150 for ADBE...
# Result: {'company_name': 'CIK-0000796343', 'stock_name': 'ADBE', 'filing_time': '2024-12-11 16:06:49', 'new_product': None, 'product_description': None}
#
#  Processing filing 93/150 for ADBE...
# Result: {'company_name': 'CIK-0000796343', 'stock_name': 'ADBE', 'filing_time': '2024-09-12 16:06:12', 'new_product': None, 'product_description': None}
#
#  Processing filing 94/150 for ADBE...
# Result: {'company_name': 'CIK-0000796343', 'stock_name': 'ADBE', 'filing_time': '2024-08-08 16:05:40', 'new_product': None, 'product_description': None}
#
#  Processing filing 95/150 for ADBE...
# Result: {'company_name': 'CIK-0000796343', 'stock_name': 'ADBE', 'filing_time': '2024-07-18 16:15:45', 'new_product': None, 'product_description': None}
#
#  Processing filing 96/150 for ADBE...
# Result: {'company_name': 'CIK-0000796343', 'stock_name': 'ADBE', 'filing_time': '2024-06-13 16:06:10', 'new_product': None, 'product_description': None}
#
#  Processing filing 97/150 for ORCL...
# Result: {'company_name': 'CIK-0001341439', 'stock_name': 'ORCL', 'filing_time': '2025-03-10 16:13:09', 'new_product': 'Oracle AI Data Platform', 'product_description': 'A new product that connects leading AI models to analyze all private data while keeping it secure.'}
#
#  Processing filing 98/150 for ORCL...
# Result: {'company_name': 'CIK-0001341439', 'stock_name': 'ORCL', 'filing_time': '2025-02-26 17:03:26', 'new_product': None, 'product_description': None}
#
#  Processing filing 99/150 for ORCL...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001341439', 'stock_name': 'ORCL', 'filing_time': '2025-02-03 16:15:14', 'new_product': None, 'product_description': None}
#
#  Processing filing 100/150 for ORCL...
# Result: {'company_name': 'CIK-0001341439', 'stock_name': 'ORCL', 'filing_time': '2025-01-22 16:19:32', 'new_product': None, 'product_description': None}
#
#  Processing filing 101/150 for ORCL...
# Result: {'company_name': 'CIK-0001341439', 'stock_name': 'ORCL', 'filing_time': '2025-01-13 16:30:14', 'new_product': None, 'product_description': None}
#
#  Processing filing 102/150 for ORCL...
# Result: {'company_name': 'CIK-0001341439', 'stock_name': 'ORCL', 'filing_time': '2024-12-09 16:13:45', 'new_product': 'Oracle AI Cloud Infrastructure', 'product_description': 'A cloud infrastructure service with increased AI capabilities, offering faster and less expensive AI training compared to other clouds.'}
#
#  Processing filing 103/150 for ORCL...
# Error extracting filing text: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  AssertionError: expected name token at '<![]FQ>%O.X#4S4%\\ K@'
# Skipping due to missing text.
#
#  Processing filing 104/150 for ORCL...
# Result: {'company_name': 'CIK-0001341439', 'stock_name': 'ORCL', 'filing_time': '2024-09-27 16:14:32', 'new_product': None, 'product_description': 'This filing does not announce a new product or service.'}
#
#  Processing filing 105/150 for IBM...
# Result: {'company_name': 'CIK-0000051143', 'stock_name': 'IBM', 'filing_time': '2025-03-12 16:48:40', 'new_product': 'Hybrid Cloud', 'product_description': 'IBM updates its reported revenue category for Hybrid Cloud within the Software segment'}
#
#  Processing filing 106/150 for IBM...
# Result: {'company_name': 'CIK-0000051143', 'stock_name': 'IBM', 'filing_time': '2025-02-07 16:17:05', 'new_product': None, 'product_description': 'No new product or service is announced in the provided filing.'}
#
#  Processing filing 107/150 for IBM...
# Result: {'company_name': 'CIK-0000051143', 'stock_name': 'IBM', 'filing_time': '2025-02-04 17:24:05', 'new_product': None, 'product_description': 'No new product is explicitly introduced or announced in the provided filing.'}
#
#  Processing filing 108/150 for IBM...
# Result: {'company_name': 'CIK-0000051143', 'stock_name': 'IBM', 'filing_time': '2025-01-30 16:14:18', 'new_product': 'z17 Mainframe', 'product_description': 'Next generation z17 mainframe system launch in the middle of 2025'}
#
#  Processing filing 109/150 for IBM...
# Result: {'company_name': 'CIK-0000051143', 'stock_name': 'IBM', 'filing_time': '2025-01-29 16:16:40', 'new_product': 'Red Hat', 'product_description': 'A leading open-source enterprise software platform for cloud, hybrid cloud, and on-premises environments'}
#
#  Processing filing 110/150 for IBM...
# Result: {'company_name': 'CIK-0000051143', 'stock_name': 'IBM', 'filing_time': '2024-12-09 16:27:24', 'new_product': None, 'product_description': 'No new product announced in this filing.'}
#
#  Processing filing 111/150 for IBM...
# Result: {'company_name': 'CIK-0000051143', 'stock_name': 'IBM', 'filing_time': '2024-10-24 16:12:46', 'new_product': 'Red Hat AI', 'product_description': 'AI capabilities announced for Red Hat, a leading open-source software company acquired by IBM in 2018'}
#
#  Processing filing 112/150 for IBM...
# Result: {'company_name': 'CIK-0000051143', 'stock_name': 'IBM', 'filing_time': '2024-10-23 16:12:01', 'new_product': 'IBM Generative AI', 'product_description': "IBM's Generative AI, a service offering that provides trusted and cost-effective AI models with performance leadership. The product book of business now stands at more than $3 b..."}
#
#  Processing filing 113/150 for UBER...
# Result: {'company_name': 'CIK-0001543151', 'stock_name': 'UBER', 'filing_time': '2025-02-07 17:25:18', 'new_product': None, 'product_description': None}
#
#  Processing filing 114/150 for UBER...
# Result: {'company_name': 'CIK-0001543151', 'stock_name': 'UBER', 'filing_time': '2025-02-05 06:56:00', 'new_product': None, 'product_description': 'No new product announced in this filing'}
#
#  Processing filing 115/150 for UBER...
# Result: {'company_name': 'CIK-0001543151', 'stock_name': 'UBER', 'filing_time': '2024-10-31 06:55:56', 'new_product': 'Rider Verification (nationwide)', 'product_description': "Uber's new safety feature for drivers, Rider Verification, introduced nationwide"}
#
#  Processing filing 116/150 for UBER...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001543151', 'stock_name': 'UBER', 'filing_time': '2024-09-27 06:45:16', 'new_product': None, 'product_description': None}
#
#  Processing filing 117/150 for UBER...
# Result: {'company_name': 'CIK-0001543151', 'stock_name': 'UBER', 'filing_time': '2024-09-09 16:17:02', 'new_product': None, 'product_description': 'No new product or service is announced in this filing.'}
#
#  Processing filing 118/150 for UBER...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001543151', 'stock_name': 'UBER', 'filing_time': '2024-08-06 06:58:28', 'new_product': None, 'product_description': None}
#
#  Processing filing 119/150 for UBER...
# Result: {'company_name': 'CIK-0001543151', 'stock_name': 'UBER', 'filing_time': '2024-08-02 16:39:39', 'new_product': None, 'product_description': None}
#
#  Processing filing 120/150 for UBER...
# Result: {'company_name': 'CIK-0001543151', 'stock_name': 'UBER', 'filing_time': '2024-05-14 06:00:31', 'new_product': 'Uber Eats Taiwan expansion', 'product_description': "Expansion of Uber Eats service into foodpanda's delivery business in Taiwan, offering improved experience for consumers, merchants, and delivery partners."}
#
#  Processing filing 121/150 for PLTR...
# Result: {'company_name': 'CIK-0001321655', 'stock_name': 'PLTR', 'filing_time': '2025-02-27 18:02:46', 'new_product': None, 'product_description': 'No new product announced in this filing'}
#
#  Processing filing 122/150 for PLTR...
# Result: {'company_name': 'CIK-0001321655', 'stock_name': 'PLTR', 'filing_time': '2025-02-03 16:07:17', 'new_product': None, 'product_description': 'No new product was explicitly announced in this filing.'}
#
#  Processing filing 123/150 for PLTR...
# Result: {'company_name': 'CIK-0001321655', 'stock_name': 'PLTR', 'filing_time': '2024-11-14 16:08:10', 'new_product': None, 'product_description': 'No new product announced in the filing.'}
#
#  Processing filing 124/150 for PLTR...
# Result: {'company_name': 'CIK-0001321655', 'stock_name': 'PLTR', 'filing_time': '2024-11-04 16:07:10', 'new_product': None, 'product_description': 'No new product is explicitly introduced or announced in the provided filing.'}
#
#  Processing filing 125/150 for PLTR...
# Result: {'company_name': 'CIK-0001321655', 'stock_name': 'PLTR', 'filing_time': '2024-08-05 16:08:01', 'new_product': None, 'product_description': 'No new product announced in this filing.'}
#
#  Processing filing 126/150 for PLTR...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001321655', 'stock_name': 'PLTR', 'filing_time': '2024-06-07 18:55:41', 'new_product': None, 'product_description': None}
#
#  Processing filing 127/150 for PLTR...
# Result: {'company_name': 'CIK-0001321655', 'stock_name': 'PLTR', 'filing_time': '2024-05-06 16:06:05', 'new_product': None, 'product_description': None}
#
#  Processing filing 128/150 for PLTR...
# Result: {'company_name': 'CIK-0001321655', 'stock_name': 'PLTR', 'filing_time': '2024-02-05 16:07:25', 'new_product': None, 'product_description': 'No new product announced in this filing'}
#
#  Processing filing 129/150 for SNOW...
# Result: {'company_name': 'CIK-0001640147', 'stock_name': 'SNOW', 'filing_time': '2025-03-06 08:55:18', 'new_product': None, 'product_description': None}
#
#  Processing filing 130/150 for SNOW...
# Result: {'company_name': 'CIK-0001640147', 'stock_name': 'SNOW', 'filing_time': '2025-02-26 16:09:30', 'new_product': None, 'product_description': 'No new product or service is explicitly introduced or announced in this filing.'}
#
#  Processing filing 131/150 for SNOW...
# Result: {'company_name': 'CIK-0001640147', 'stock_name': 'SNOW', 'filing_time': '2025-02-26 16:07:28', 'new_product': None, 'product_description': 'No new product announced in this filing.'}
#
#  Processing filing 132/150 for SNOW...
# Result: {'company_name': 'CIK-0001640147', 'stock_name': 'SNOW', 'filing_time': '2024-11-20 16:07:11', 'new_product': None, 'product_description': None}
#
#  Processing filing 133/150 for SNOW...
# Result: {'company_name': 'CIK-0001640147', 'stock_name': 'SNOW', 'filing_time': '2024-09-27 16:08:53', 'new_product': None, 'product_description': None}
#
#  Processing filing 134/150 for SNOW...
# Result: {'company_name': 'CIK-0001640147', 'stock_name': 'SNOW', 'filing_time': '2024-08-21 16:07:10', 'new_product': None, 'product_description': None}
#
#  Processing filing 135/150 for SNOW...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001640147', 'stock_name': 'SNOW', 'filing_time': '2024-07-05 17:13:33', 'new_product': None, 'product_description': None}
#
#  Processing filing 136/150 for SNOW...
# Result: {'company_name': 'CIK-0001640147', 'stock_name': 'SNOW', 'filing_time': '2024-07-02 16:55:18', 'new_product': None, 'product_description': None}
#
#  Processing filing 137/150 for ROKU...
# Result: {'company_name': 'CIK-0001428439', 'stock_name': 'ROKU', 'filing_time': '2025-02-13 16:05:08', 'new_product': None, 'product_description': None}
#
#  Processing filing 138/150 for ROKU...
# Result: {'company_name': 'CIK-0001428439', 'stock_name': 'ROKU', 'filing_time': '2025-01-07 08:45:19', 'new_product': None, 'product_description': None}
#
#  Processing filing 139/150 for ROKU...
# Model API call failed: Expecting ',' delimiter: line 10 column 118 (char 485)
# Result: {'company_name': 'CIK-0001428439', 'stock_name': 'ROKU', 'filing_time': '2024-10-30 16:05:20', 'new_product': None, 'product_description': None}
#
#  Processing filing 140/150 for ROKU...
# Result: {'company_name': 'CIK-0001428439', 'stock_name': 'ROKU', 'filing_time': '2024-09-26 16:08:18', 'new_product': 'Roku Stock Options (under Executive Supplemental Stock Option Program)', 'product_description': 'Options to purchase Roku shares granted to executives under the Executive Supplemental Stock Option Program'}
#
#  Processing filing 141/150 for ROKU...
# Model API call failed: Expecting value: line 1 column 1 (char 0)
# Result: {'company_name': 'CIK-0001428439', 'stock_name': 'ROKU', 'filing_time': '2024-09-17 16:18:08', 'new_product': None, 'product_description': None}
#
#  Processing filing 142/150 for ROKU...
# Result: {'company_name': 'CIK-0001428439', 'stock_name': 'ROKU', 'filing_time': '2024-08-01 16:12:58', 'new_product': None, 'product_description': None}
#
#  Processing filing 143/150 for ROKU...
# Result: {'company_name': 'CIK-0001428439', 'stock_name': 'ROKU', 'filing_time': '2024-06-07 16:13:52', 'new_product': None, 'product_description': None}
#
#  Processing filing 144/150 for ROKU...
# Result: {'company_name': 'CIK-0001428439', 'stock_name': 'ROKU', 'filing_time': '2024-04-25 16:05:40', 'new_product': None, 'product_description': None}
#
#  Processing filing 145/150 for COIN...
# Result: {'company_name': 'CIK-0001679788', 'stock_name': 'COIN', 'filing_time': '2025-02-21 08:15:25', 'new_product': None, 'product_description': None}
#
#  Processing filing 146/150 for COIN...
# Result: {'company_name': 'CIK-0001679788', 'stock_name': 'COIN', 'filing_time': '2025-02-13 16:10:21', 'new_product': 'Base Layer 2 Platform', 'product_description': 'A blockchain scaling solution to make crypto payments easier for consumers and businesses'}
#
#  Processing filing 147/150 for COIN...
# Result: {'company_name': 'CIK-0001679788', 'stock_name': 'COIN', 'filing_time': '2024-10-30 16:10:05', 'new_product': 'Integration of stablecoins across product suite', 'product_description': "Coinbase is integrating stablecoins into its product suite to enhance the cryptoeconomy's utility"}
#
#  Processing filing 148/150 for COIN...
# Result: {'company_name': 'CIK-0001679788', 'stock_name': 'COIN', 'filing_time': '2024-08-01 16:12:12', 'new_product': 'Base Layer 2 solution', 'product_description': 'Improves efficiency, speed, and lowers costs in on-chain transactions'}
#
#  Processing filing 149/150 for COIN...
# Result: {'company_name': 'CIK-0001679788', 'stock_name': 'COIN', 'filing_time': '2024-07-25 16:03:30', 'new_product': None, 'product_description': None}
#
#  Processing filing 150/150 for COIN...
# Result: {'company_name': 'CIK-0001679788', 'stock_name': 'COIN', 'filing_time': '2024-06-20 16:05:57', 'new_product': None, 'product_description': None}
#
#  Saved to multi_ticker_8k_products.csv
